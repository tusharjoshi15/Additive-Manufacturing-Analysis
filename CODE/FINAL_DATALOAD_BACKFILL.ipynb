# %% [markdown]
# loading and processing all .gz files 331

# %%
import os
import polars as pl
import glob

# --- Configuration ---
raw_data_folder = "/Users/tusharjoshi/Desktop/ProjectWorkAll/Dissertation /DATA" 

# Define all 15 fields and their target types.
# We no longer need separate top_level_fields_schema and nested_sensor_fields_schema
# as the extraction logic will be unified.
all_fields_target_schema = {
    "check": pl.String,
    "date": pl.String, # Will be parsed to Datetime later
    "id": pl.String,    
    "state": pl.String, 
    "tempBed": pl.Float64,
    "targetBed": pl.Float64,
    "tempNozzle": pl.Float64,
    "targetNozzle": pl.Float64,
    "axisZ": pl.Float64,
    "axisX": pl.Float64,
    "axisY": pl.Float64,
    "flow": pl.Float64,
    "speed": pl.Float64,
    "fanHotend": pl.Float64,
    "fanPrint": pl.Float64,
}

all_fields_order = list(all_fields_target_schema.keys()) # For final selection/ordering


# --- Main Processing Logic ---
all_gz_files = sorted(glob.glob(os.path.join(raw_data_folder, "**/*.gz"), recursive=True))
print(f"Found {len(all_gz_files)} .gz files to process across all subfolders.")

if not all_gz_files:
    print("No .gz files found in the specified folder or its subfolders. Exiting.")
else:
    processed_dfs_list = [] 

    for i, gz_file_path in enumerate(all_gz_files):
        file_name = os.path.basename(gz_file_path)
        print(f"Processing file {i+1}/{len(all_gz_files)}: {file_name}")

        df_raw = pl.read_ndjson(gz_file_path)

        expressions_to_apply = []

        for field_name, field_type in all_fields_target_schema.items():
            if field_name in df_raw.columns:
                # Case 1: Field is top-level
                expressions_to_apply.append(pl.col(field_name).cast(field_type, strict=False))
            elif 'data' in df_raw.columns and isinstance(df_raw.schema['data'], pl.Struct) and field_name in [f.name for f in df_raw.schema['data'].fields]:
                # Case 2: Field is nested in 'data' struct
                expressions_to_apply.append(pl.col("data").struct.field(field_name).alias(field_name).cast(field_type, strict=False))
            else:
                # Case 3: Field is missing from both top-level and 'data' struct
                expressions_to_apply.append(pl.lit(None, dtype=field_type).alias(field_name))
        
        # Apply all expressions to the raw DataFrame
        current_df_processed = df_raw.with_columns(expressions_to_apply)
        
        # Drop the original 'data' column if it exists and is no longer needed
        if 'data' in current_df_processed.columns:
            current_df_processed = current_df_processed.drop("data")

        # Final selection and reordering of all columns
        current_df_processed = current_df_processed.select(all_fields_order)

        processed_dfs_list.append(current_df_processed)
        print(f"  Processed {len(current_df_processed):,} records from {file_name}")

    print(f"\nFinished processing all .gz files. {len(processed_dfs_list)} DataFrames are ready.")
# Out:
# Found 331 .gz files to process across all subfolders.
# Processing file 1/331: 2024-04-03-prusa.gz
#   Processed 214,770 records from 2024-04-03-prusa.gz
# Processing file 2/331: 2024-04-04-prusa.gz
#   Processed 477,585 records from 2024-04-04-prusa.gz
# Processing file 3/331: 2024-04-05-prusa.gz
#   Processed 458,436 records from 2024-04-05-prusa.gz
# Processing file 4/331: 2024-04-06-prusa.gz
#   Processed 468,234 records from 2024-04-06-prusa.gz
# Processing file 5/331: 2024-04-07-prusa.gz
#   Processed 472,404 records from 2024-04-07-prusa.gz
# Processing file 327/331: 2025-04-25-prusa.gz
#   Processed 258,372 records from 2025-04-25-prusa.gz
# Processing file 328/331: 2025-04-26-prusa.gz
#   Processed 258,372 records from 2025-04-26-prusa.gz
# Processing file 329/331: 2025-04-27-prusa.gz
#   Processed 258,348 records from 2025-04-27-prusa.gz
# Processing file 330/331: 2025-04-28-prusa.gz
#   Processed 258,366 records from 2025-04-28-prusa.gz
# Processing file 331/331: 2025-04-29-prusa.gz
#   Processed 258,396 records from 2025-04-29-prusa.gz
#
# Finished processing all .gz files. 331 DataFrames are ready.

# %% [markdown]
# Global backfilling and data type enforcement
#
# Explanation:
#
# fields_to_backfill_globally: This list explicitly names all 15 columns that will have the forward_fill applied.
#
# final_schema_cast: This dictionary defines the final, desired data type for each of your 15 columns after backfilling. Notice date is now pl.Datetime.
#
# pl.concat(processed_dfs_list): This is the critical step that combines all your individual DataFrames into one.
#
# df_combined.sort(["id", "date"]): This is absolutely crucial. It ensures that all records for a given id are grouped together and ordered chronologically. Without this, forward_fill would not work correctly across the entire dataset.
#
# forward_fill().over("id"): Applied to the sorted df_combined, this now allows values to propagate from earlier batches into later batches for the same id.
#
# Final Type Enforcement: We re-apply cast for all columns. For date, we use strptime to convert the string dates (from initial loading) into proper Polars Datetime objects. strict=False is used for all casts to ensure that any values that still cannot be converted (e.g., truly invalid numbers after backfilling) become NULLs instead of crashing the process.

# %%
# --- Define fields to backfill globally ---
# These are the fields where you want forward_fill to apply globally per ID
fields_to_backfill_globally = [
    "check", "state", "tempBed", "targetBed", "tempNozzle", "targetNozzle",
    "axisZ", "axisX", "axisY", "flow", "speed", "fanHotend", "fanPrint"
]

# --- Define all 15 fields and their target types for final casting ---
# This ensures final consistency after backfilling
final_schema_cast = {
    "check": pl.String,
    "date": pl.Datetime, # Now we will cast to actual Datetime object
    "id": pl.String,    
    "state": pl.String, 
    "tempBed": pl.Float64,
    "targetBed": pl.Float64,
    "tempNozzle": pl.Float64,
    "targetNozzle": pl.Float64,
    "axisZ": pl.Float64,
    "axisX": pl.Float64,
    "axisY": pl.Float64,
    "flow": pl.Float64,
    "speed": pl.Float64,
    "fanHotend": pl.Float64,
    "fanPrint": pl.Float64,
}

# --- Main Processing Logic for Global Backfilling ---
if not processed_dfs_list:
    print("No DataFrames found in 'processed_dfs_list'. Please run Step 1 first.")
else:
    print("Concatenating all pre-processed DataFrames...")
    df_combined = pl.concat(processed_dfs_list)
    print(f"Combined DataFrame loaded successfully with {df_combined.shape[0]:,} rows.")

    # --- Apply global backfilling across the entire combined DataFrame ---
    print("Sorting DataFrame by ID and Date for global forward-fill...")
    # It's crucial to sort by ID and then Date for correct forward-fill within each ID group
    df_combined = df_combined.sort(["id", "date"]) 
    print("Sorting complete.")

    print("Applying global forward-fill across all batches for each ID...")
    df_combined = df_combined.with_columns([
        pl.col(field).forward_fill().over("id")
        for field in fields_to_backfill_globally
    ])
    print("Global forward-fill complete.")

    # --- Final Data Type Enforcement ---
    # Re-cast 'date' to actual Datetime object and ensure all other types are final
    print("Enforcing final data types on the combined DataFrame...")
    for col_name, col_type in final_schema_cast.items():
        # For 'date' column, we use strptime to parse from string to Datetime
        if col_name == "date" and col_type == pl.Datetime:
            df_combined = df_combined.with_columns(
                pl.col(col_name).str.strptime(pl.Datetime, format="%Y-%m-%dT%H:%M:%S%.f%Z", strict=False).alias(col_name)
            )
        else:
            df_combined = df_combined.with_columns(
                pl.col(col_name).cast(col_type, strict=False) # strict=False converts unparseable to NULL
            )
    print("Final data type enforcement complete.")

    # The 'df_combined' DataFrame now holds your fully backfilled and type-enforced data.
    # We will use this DataFrame in the next step.
    print(f"\nStep 2 complete. Final DataFrame has {df_combined.shape[0]:,} rows and {len(df_combined.columns)} columns.")
# Out:
# Concatenating all pre-processed DataFrames...
# Combined DataFrame loaded successfully with 94,869,699 rows.
# Sorting DataFrame by ID and Date for global forward-fill...
# Sorting complete.
# Applying global forward-fill across all batches for each ID...
# Global forward-fill complete.
# Enforcing final data types on the combined DataFrame...
# Final data type enforcement complete.
#
# Step 2 complete. Final DataFrame has 94,869,699 rows and 15 columns.

# %% [markdown]
# let us check the null values for each column now

# %%
print("\n--- Verifying Nulls in the Globally Backfilled DataFrame ---")
print(f"{'Field':<20} {'Total Nulls':<15} {'Percentage':<10}")
print("-" * 50)

total_records_in_df_combined = df_combined.shape[0]

# Iterate through all columns in the combined DataFrame
for col_name in df_combined.columns:
    null_count = df_combined[col_name].null_count()
    
    null_pct = (null_count / total_records_in_df_combined * 100) if total_records_in_df_combined > 0 else 0
    
    print(f"{col_name:<20}: {null_count:<15,} ({null_pct:<6.2f}%)")

print("-" * 50)
print(f"Total records processed: {total_records_in_df_combined:,}")

# Store the results for later reference if needed
global_null_summary = {
    col_name: {"null_count": df_combined[col_name].null_count(), 
               "null_percentage": (df_combined[col_name].null_count() / total_records_in_df_combined * 100) if total_records_in_df_combined > 0 else 0}
    for col_name in df_combined.columns
}
# Out:
# --- Verifying Nulls in the Globally Backfilled DataFrame ---
# Field                Total Nulls     Percentage
# --------------------------------------------------
# check               : 0               (0.00  %)
# date                : 0               (0.00  %)
# id                  : 0               (0.00  %)
# state               : 0               (0.00  %)
# tempBed             : 0               (0.00  %)
# targetBed           : 0               (0.00  %)
# tempNozzle          : 0               (0.00  %)
# targetNozzle        : 0               (0.00  %)
# axisZ               : 0               (0.00  %)
# axisX               : 0               (0.00  %)
# axisY               : 0               (0.00  %)
# flow                : 0               (0.00  %)
# speed               : 0               (0.00  %)
# fanHotend           : 0               (0.00  %)
# fanPrint            : 0               (0.00  %)
# --------------------------------------------------
# Total records processed: 94,869,699

# %% [markdown]
# perfect now we export it to mysql

# %%
import os
import polars as pl
import pymysql
from sqlalchemy import create_engine, text



# --- Configuration ---
# MySQL Database Connection Details

DB_HOST = "localhost"
DB_USER = "root"       # Use 'root' if you skipped creating a dedicated user
DB_PASSWORD = "admintushar15" # Replace with your MySQL root password
DB_NAME = "printer_data_db" # The database name you created in DBeaver
TABLE_NAME_IN_DB = "PrinterData" # Name of the table to create in MySQL

batch_size = 100000 # Define a reasonable batch size for insertion (e.g., 100,000 rows)

# --- Main Export Process to MySQL ---
try:
    # Connect to MySQL using pymysql
    conn = pymysql.connect(host=DB_HOST, user=DB_USER, password=DB_PASSWORD, database=DB_NAME)
    cursor = conn.cursor()

    print(f"\nExporting data to MySQL database '{DB_NAME}' table '{TABLE_NAME_IN_DB}' in batches...")

    # Drop table if it exists to ensure a clean export
    cursor.execute(f"DROP TABLE IF EXISTS `{TABLE_NAME_IN_DB}`;")
    
    # Create table schema in MySQL based on Polars DataFrame columns and types
    type_mapping = {
        pl.String: "TEXT",
        pl.Float64: "DOUBLE", # MySQL uses DOUBLE for floating point numbers
        pl.Datetime: "DATETIME" # MySQL DATETIME type
    }
    columns_sql_defs = []
    for col_name, dtype in df_combined.schema.items():
        mysql_type = type_mapping.get(dtype, "TEXT") 
        columns_sql_defs.append(f'`{col_name}` {mysql_type}') 
    
    create_table_sql = f"CREATE TABLE `{TABLE_NAME_IN_DB}` ({', '.join(columns_sql_defs)});"
    cursor.execute(create_table_sql)
    print(f"Created table '{TABLE_NAME_IN_DB}' in MySQL.")

    # Prepare the INSERT statement
    placeholders = ", ".join(["%s" for _ in df_combined.columns]) # Use %s for pymysql placeholders
    insert_sql = f"INSERT INTO `{TABLE_NAME_IN_DB}` VALUES ({placeholders});"

    # Iterate over the Polars DataFrame in batches and insert
    total_inserted_rows = 0
    for batch_start in range(0, df_combined.shape[0], batch_size):
        batch_end = min(batch_start + batch_size, df_combined.shape[0])
        df_batch_to_insert = df_combined.slice(batch_start, batch_end - batch_start)
        
        # Convert Polars batch to a list of tuples for pymysql.executemany
        rows_to_insert = []
        for row_data in df_batch_to_insert.iter_rows():
            formatted_row = []
            for col_val, col_name in zip(row_data, df_combined.columns): # Iterate with col_name to check type
                if isinstance(col_val, pl.Datetime):
                    formatted_row.append(col_val.isoformat()) # Convert datetime to ISO string
                else:
                    formatted_row.append(col_val)
            rows_to_insert.append(tuple(formatted_row))

        cursor.executemany(insert_sql, rows_to_insert)
        conn.commit() # Commit after each batch
        total_inserted_rows += len(rows_to_insert)
        print(f"  Inserted {len(rows_to_insert)} rows. Total inserted: {total_inserted_rows}")

    print(f"Successfully exported all data to MySQL table '{TABLE_NAME_IN_DB}'.")

except Exception as e:
    print(f"\nAn error occurred during the MySQL export process: {e}")
    print("Please check:")
    print("- MySQL server is running and accessible.")
    print("- Database name, username, and password are correct.")
    print("- You have sufficient privileges to create/write to the table.")
    print("- That you have enough disk space on your MySQL server.")

finally:
    if 'conn' in locals() and conn.open: 
        conn.close()
        print("MySQL connection closed.")
# Out:
# Exporting data to MySQL database 'printer_data_db' table 'PrinterData' in batches...
# Created table 'PrinterData' in MySQL.
#   Inserted 100000 rows. Total inserted: 100000
#   Inserted 100000 rows. Total inserted: 200000
#   Inserted 100000 rows. Total inserted: 300000
#   Inserted 100000 rows. Total inserted: 400000
#   Inserted 100000 rows. Total inserted: 500000
#   Inserted 100000 rows. Total inserted: 600000
#   Inserted 100000 rows. Total inserted: 700000
#   Inserted 100000 rows. Total inserted: 800000
#   Inserted 100000 rows. Total inserted: 900000
#   Inserted 100000 rows. Total inserted: 1000000
#   Inserted 100000 rows. Total inserted: 1100000
#   Inserted 100000 rows. Total inserted: 1200000
#   Inserted 100000 rows. Total inserted: 1300000
#   Inserted 100000 rows. Total inserted: 1400000
#   Inserted 100000 rows. Total inserted: 1500000
#   Inserted 100000 rows. Total inserted: 1600000
#   Inserted 100000 rows. Total inserted: 1700000
#   Inserted 100000 rows. Total inserted: 1800000
#   Inserted 100000 rows. Total inserted: 1900000
#   Inserted 100000 rows. Total inserted: 2000000
#   Inserted 100000 rows. Total inserted: 2100000
#   Inserted 100000 rows. Total inserted: 2200000
#   Inserted 100000 rows. Total inserted: 2300000
#   Inserted 100000 rows. Total inserted: 2400000
#   Inserted 100000 rows. Total inserted: 2500000
#   Inserted 100000 rows. Total inserted: 2600000
#   Inserted 100000 rows. Total inserted: 2700000
#   Inserted 100000 rows. Total inserted: 2800000
#   Inserted 100000 rows. Total inserted: 2900000
#   Inserted 100000 rows. Total inserted: 3000000
#   Inserted 100000 rows. Total inserted: 3100000
#   Inserted 100000 rows. Total inserted: 3200000
#   Inserted 100000 rows. Total inserted: 3300000
#   Inserted 100000 rows. Total inserted: 3400000
#   Inserted 100000 rows. Total inserted: 3500000
#   Inserted 100000 rows. Total inserted: 3600000
#   Inserted 100000 rows. Total inserted: 3700000
#   Inserted 100000 rows. Total inserted: 3800000
#   Inserted 100000 rows. Total inserted: 3900000
#   Inserted 100000 rows. Total inserted: 4000000
#   Inserted 100000 rows. Total inserted: 4100000
#   Inserted 100000 rows. Total inserted: 4200000
#   Inserted 100000 rows. Total inserted: 4300000
#   Inserted 100000 rows. Total inserted: 4400000
#   Inserted 100000 rows. Total inserted: 4500000
#   Inserted 100000 rows. Total inserted: 4600000
#   Inserted 100000 rows. Total inserted: 4700000
#   Inserted 100000 rows. Total inserted: 4800000
#   Inserted 100000 rows. Total inserted: 4900000
#   Inserted 100000 rows. Total inserted: 5000000
#   Inserted 100000 rows. Total inserted: 5100000
#   Inserted 100000 rows. Total inserted: 5200000
#   Inserted 100000 rows. Total inserted: 5300000
#   Inserted 100000 rows. Total inserted: 5400000
#   Inserted 100000 rows. Total inserted: 5500000
#   Inserted 100000 rows. Total inserted: 5600000
#   Inserted 100000 rows. Total inserted: 5700000
#   Inserted 100000 rows. Total inserted: 5800000
#   Inserted 100000 rows. Total inserted: 5900000
#   Inserted 100000 rows. Total inserted: 6000000
#   Inserted 100000 rows. Total inserted: 6100000
#   Inserted 100000 rows. Total inserted: 6200000
#   Inserted 100000 rows. Total inserted: 6300000
#   Inserted 100000 rows. Total inserted: 6400000
#   Inserted 100000 rows. Total inserted: 6500000
#   Inserted 100000 rows. Total inserted: 6600000
#   Inserted 100000 rows. Total inserted: 6700000
#   Inserted 100000 rows. Total inserted: 6800000
#   Inserted 100000 rows. Total inserted: 6900000
#   Inserted 100000 rows. Total inserted: 7000000
#   Inserted 100000 rows. Total inserted: 7100000
#   Inserted 100000 rows. Total inserted: 7200000
#   Inserted 100000 rows. Total inserted: 7300000
#   Inserted 100000 rows. Total inserted: 7400000
#   Inserted 100000 rows. Total inserted: 7500000
#   Inserted 100000 rows. Total inserted: 7600000
#   Inserted 100000 rows. Total inserted: 7700000
#   Inserted 100000 rows. Total inserted: 7800000
#   Inserted 100000 rows. Total inserted: 7900000
#   Inserted 100000 rows. Total inserted: 8000000
#   Inserted 100000 rows. Total inserted: 8100000
#   Inserted 100000 rows. Total inserted: 8200000
#   Inserted 100000 rows. Total inserted: 8300000
#   Inserted 100000 rows. Total inserted: 8400000
#   Inserted 100000 rows. Total inserted: 8500000
#   Inserted 100000 rows. Total inserted: 8600000
#   Inserted 100000 rows. Total inserted: 8700000
#   Inserted 100000 rows. Total inserted: 8800000
#   Inserted 100000 rows. Total inserted: 8900000
#   Inserted 100000 rows. Total inserted: 9000000
#   Inserted 100000 rows. Total inserted: 9100000
#   Inserted 100000 rows. Total inserted: 9200000
#   Inserted 100000 rows. Total inserted: 9300000
#   Inserted 100000 rows. Total inserted: 9400000
#   Inserted 100000 rows. Total inserted: 9500000
#   Inserted 100000 rows. Total inserted: 9600000
#   Inserted 100000 rows. Total inserted: 9700000
#   Inserted 100000 rows. Total inserted: 9800000
#   Inserted 100000 rows. Total inserted: 9900000
#   Inserted 100000 rows. Total inserted: 10000000
#   Inserted 100000 rows. Total inserted: 10100000
#   Inserted 100000 rows. Total inserted: 10200000
#   Inserted 100000 rows. Total inserted: 10300000
#   Inserted 100000 rows. Total inserted: 10400000
#   Inserted 100000 rows. Total inserted: 10500000
#   Inserted 100000 rows. Total inserted: 10600000
#   Inserted 100000 rows. Total inserted: 10700000
#   Inserted 100000 rows. Total inserted: 10800000
#   Inserted 100000 rows. Total inserted: 10900000
#   Inserted 100000 rows. Total inserted: 11000000
#   Inserted 100000 rows. Total inserted: 11100000
#   Inserted 100000 rows. Total inserted: 11200000
#   Inserted 100000 rows. Total inserted: 11300000
#   Inserted 100000 rows. Total inserted: 11400000
#   Inserted 100000 rows. Total inserted: 11500000
#   Inserted 100000 rows. Total inserted: 11600000
#   Inserted 100000 rows. Total inserted: 11700000
#   Inserted 100000 rows. Total inserted: 11800000
#   Inserted 100000 rows. Total inserted: 11900000
#   Inserted 100000 rows. Total inserted: 12000000
#   Inserted 100000 rows. Total inserted: 12100000
#   Inserted 100000 rows. Total inserted: 12200000
#   Inserted 100000 rows. Total inserted: 12300000
#   Inserted 100000 rows. Total inserted: 12400000
#   Inserted 100000 rows. Total inserted: 12500000
#   Inserted 100000 rows. Total inserted: 12600000
#   Inserted 100000 rows. Total inserted: 12700000
#   Inserted 100000 rows. Total inserted: 12800000
#   Inserted 100000 rows. Total inserted: 12900000
#   Inserted 100000 rows. Total inserted: 13000000
#   Inserted 100000 rows. Total inserted: 13100000
#   Inserted 100000 rows. Total inserted: 13200000
#   Inserted 100000 rows. Total inserted: 13300000
#   Inserted 100000 rows. Total inserted: 13400000
#   Inserted 100000 rows. Total inserted: 13500000
#   Inserted 100000 rows. Total inserted: 13600000
#   Inserted 100000 rows. Total inserted: 13700000
#   Inserted 100000 rows. Total inserted: 13800000
#   Inserted 100000 rows. Total inserted: 13900000
#   Inserted 100000 rows. Total inserted: 14000000
#   Inserted 100000 rows. Total inserted: 14100000
#   Inserted 100000 rows. Total inserted: 14200000
#   Inserted 100000 rows. Total inserted: 14300000
#   Inserted 100000 rows. Total inserted: 14400000
#   Inserted 100000 rows. Total inserted: 14500000
#   Inserted 100000 rows. Total inserted: 14600000
#   Inserted 100000 rows. Total inserted: 14700000
#   Inserted 100000 rows. Total inserted: 14800000
#   Inserted 100000 rows. Total inserted: 14900000
#   Inserted 100000 rows. Total inserted: 15000000
#   Inserted 100000 rows. Total inserted: 15100000
#   Inserted 100000 rows. Total inserted: 15200000
#   Inserted 100000 rows. Total inserted: 15300000
#   Inserted 100000 rows. Total inserted: 15400000
#   Inserted 100000 rows. Total inserted: 15500000
#   Inserted 100000 rows. Total inserted: 15600000
#   Inserted 100000 rows. Total inserted: 15700000
#   Inserted 100000 rows. Total inserted: 15800000
#   Inserted 100000 rows. Total inserted: 15900000
#   Inserted 100000 rows. Total inserted: 16000000
#   Inserted 100000 rows. Total inserted: 16100000
#   Inserted 100000 rows. Total inserted: 16200000
#   Inserted 100000 rows. Total inserted: 16300000
#   Inserted 100000 rows. Total inserted: 16400000
#   Inserted 100000 rows. Total inserted: 16500000
#   Inserted 100000 rows. Total inserted: 16600000
#   Inserted 100000 rows. Total inserted: 16700000
#   Inserted 100000 rows. Total inserted: 16800000
#   Inserted 100000 rows. Total inserted: 16900000
#   Inserted 100000 rows. Total inserted: 17000000
#   Inserted 100000 rows. Total inserted: 17100000
#   Inserted 100000 rows. Total inserted: 17200000
#   Inserted 100000 rows. Total inserted: 17300000
#   Inserted 100000 rows. Total inserted: 17400000
#   Inserted 100000 rows. Total inserted: 17500000
#   Inserted 100000 rows. Total inserted: 17600000
#   Inserted 100000 rows. Total inserted: 17700000
#   Inserted 100000 rows. Total inserted: 17800000
#   Inserted 100000 rows. Total inserted: 17900000
#   Inserted 100000 rows. Total inserted: 18000000
#   Inserted 100000 rows. Total inserted: 18100000
#   Inserted 100000 rows. Total inserted: 18200000
#   Inserted 100000 rows. Total inserted: 18300000
#   Inserted 100000 rows. Total inserted: 18400000
#   Inserted 100000 rows. Total inserted: 18500000
#   Inserted 100000 rows. Total inserted: 18600000
#   Inserted 100000 rows. Total inserted: 18700000
#   Inserted 100000 rows. Total inserted: 18800000
#   Inserted 100000 rows. Total inserted: 18900000
#   Inserted 100000 rows. Total inserted: 19000000
#   Inserted 100000 rows. Total inserted: 19100000
#   Inserted 100000 rows. Total inserted: 19200000
#   Inserted 100000 rows. Total inserted: 19300000
#   Inserted 100000 rows. Total inserted: 19400000
#   Inserted 100000 rows. Total inserted: 19500000
#   Inserted 100000 rows. Total inserted: 19600000
#   Inserted 100000 rows. Total inserted: 19700000
#   Inserted 100000 rows. Total inserted: 19800000
#   Inserted 100000 rows. Total inserted: 19900000
#   Inserted 100000 rows. Total inserted: 20000000
#   Inserted 100000 rows. Total inserted: 20100000
#   Inserted 100000 rows. Total inserted: 20200000
#   Inserted 100000 rows. Total inserted: 20300000
#   Inserted 100000 rows. Total inserted: 20400000
#   Inserted 100000 rows. Total inserted: 20500000
#   Inserted 100000 rows. Total inserted: 20600000
#   Inserted 100000 rows. Total inserted: 20700000
#   Inserted 100000 rows. Total inserted: 20800000
#   Inserted 100000 rows. Total inserted: 20900000
#   Inserted 100000 rows. Total inserted: 21000000
#   Inserted 100000 rows. Total inserted: 21100000
#   Inserted 100000 rows. Total inserted: 21200000
#   Inserted 100000 rows. Total inserted: 21300000
#   Inserted 100000 rows. Total inserted: 21400000
#   Inserted 100000 rows. Total inserted: 21500000
#   Inserted 100000 rows. Total inserted: 21600000
#   Inserted 100000 rows. Total inserted: 21700000
#   Inserted 100000 rows. Total inserted: 21800000
#   Inserted 100000 rows. Total inserted: 21900000
#   Inserted 100000 rows. Total inserted: 22000000
#   Inserted 100000 rows. Total inserted: 22100000
#   Inserted 100000 rows. Total inserted: 22200000
#   Inserted 100000 rows. Total inserted: 22300000
#   Inserted 100000 rows. Total inserted: 22400000
#   Inserted 100000 rows. Total inserted: 22500000
#   Inserted 100000 rows. Total inserted: 22600000
#   Inserted 100000 rows. Total inserted: 22700000
#   Inserted 100000 rows. Total inserted: 22800000
#   Inserted 100000 rows. Total inserted: 22900000
#   Inserted 100000 rows. Total inserted: 23000000
#   Inserted 100000 rows. Total inserted: 23100000
#   Inserted 100000 rows. Total inserted: 23200000
#   Inserted 100000 rows. Total inserted: 23300000
#   Inserted 100000 rows. Total inserted: 23400000
#   Inserted 100000 rows. Total inserted: 23500000
#   Inserted 100000 rows. Total inserted: 23600000
#   Inserted 100000 rows. Total inserted: 23700000
#   Inserted 100000 rows. Total inserted: 23800000
#   Inserted 100000 rows. Total inserted: 23900000
#   Inserted 100000 rows. Total inserted: 24000000
#   Inserted 100000 rows. Total inserted: 24100000
#   Inserted 100000 rows. Total inserted: 24200000
#   Inserted 100000 rows. Total inserted: 24300000
#   Inserted 100000 rows. Total inserted: 24400000
#   Inserted 100000 rows. Total inserted: 24500000
#   Inserted 100000 rows. Total inserted: 24600000
#   Inserted 100000 rows. Total inserted: 24700000
#   Inserted 100000 rows. Total inserted: 24800000
#   Inserted 100000 rows. Total inserted: 24900000
#   Inserted 100000 rows. Total inserted: 25000000
#   Inserted 100000 rows. Total inserted: 25100000
#   Inserted 100000 rows. Total inserted: 25200000
#   Inserted 100000 rows. Total inserted: 25300000
#   Inserted 100000 rows. Total inserted: 25400000
#   Inserted 100000 rows. Total inserted: 25500000
#   Inserted 100000 rows. Total inserted: 25600000
#   Inserted 100000 rows. Total inserted: 25700000
#   Inserted 100000 rows. Total inserted: 25800000
#   Inserted 100000 rows. Total inserted: 25900000
#   Inserted 100000 rows. Total inserted: 26000000
#   Inserted 100000 rows. Total inserted: 26100000
#   Inserted 100000 rows. Total inserted: 26200000
#   Inserted 100000 rows. Total inserted: 26300000
#   Inserted 100000 rows. Total inserted: 26400000
#   Inserted 100000 rows. Total inserted: 26500000
#   Inserted 100000 rows. Total inserted: 26600000
#   Inserted 100000 rows. Total inserted: 26700000
#   Inserted 100000 rows. Total inserted: 26800000
#   Inserted 100000 rows. Total inserted: 26900000
#   Inserted 100000 rows. Total inserted: 27000000
#   Inserted 100000 rows. Total inserted: 27100000
#   Inserted 100000 rows. Total inserted: 27200000
#   Inserted 100000 rows. Total inserted: 27300000
#   Inserted 100000 rows. Total inserted: 27400000
#   Inserted 100000 rows. Total inserted: 27500000
#   Inserted 100000 rows. Total inserted: 27600000
#   Inserted 100000 rows. Total inserted: 27700000
#   Inserted 100000 rows. Total inserted: 27800000
#   Inserted 100000 rows. Total inserted: 27900000
#   Inserted 100000 rows. Total inserted: 28000000
#   Inserted 100000 rows. Total inserted: 28100000
#   Inserted 100000 rows. Total inserted: 28200000
#   Inserted 100000 rows. Total inserted: 28300000
#   Inserted 100000 rows. Total inserted: 28400000
#   Inserted 100000 rows. Total inserted: 28500000
#   Inserted 100000 rows. Total inserted: 28600000
#   Inserted 100000 rows. Total inserted: 28700000
#   Inserted 100000 rows. Total inserted: 28800000
#   Inserted 100000 rows. Total inserted: 28900000
#   Inserted 100000 rows. Total inserted: 29000000
#   Inserted 100000 rows. Total inserted: 29100000
#   Inserted 100000 rows. Total inserted: 29200000
#   Inserted 100000 rows. Total inserted: 29300000
#   Inserted 100000 rows. Total inserted: 29400000
#   Inserted 100000 rows. Total inserted: 29500000
#   Inserted 100000 rows. Total inserted: 29600000
#   Inserted 100000 rows. Total inserted: 29700000
#   Inserted 100000 rows. Total inserted: 29800000
#   Inserted 100000 rows. Total inserted: 29900000
#   Inserted 100000 rows. Total inserted: 30000000
#   Inserted 100000 rows. Total inserted: 30100000
#   Inserted 100000 rows. Total inserted: 30200000
#   Inserted 100000 rows. Total inserted: 30300000
#   Inserted 100000 rows. Total inserted: 30400000
#   Inserted 100000 rows. Total inserted: 30500000
#   Inserted 100000 rows. Total inserted: 30600000
#   Inserted 100000 rows. Total inserted: 30700000
#   Inserted 100000 rows. Total inserted: 30800000
#   Inserted 100000 rows. Total inserted: 30900000
#   Inserted 100000 rows. Total inserted: 31000000
#   Inserted 100000 rows. Total inserted: 31100000
#   Inserted 100000 rows. Total inserted: 31200000
#   Inserted 100000 rows. Total inserted: 31300000
#   Inserted 100000 rows. Total inserted: 31400000
#   Inserted 100000 rows. Total inserted: 31500000
#   Inserted 100000 rows. Total inserted: 31600000
#   Inserted 100000 rows. Total inserted: 31700000
#   Inserted 100000 rows. Total inserted: 31800000
#   Inserted 100000 rows. Total inserted: 31900000
#   Inserted 100000 rows. Total inserted: 32000000
#   Inserted 100000 rows. Total inserted: 32100000
#   Inserted 100000 rows. Total inserted: 32200000
#   Inserted 100000 rows. Total inserted: 32300000
#   Inserted 100000 rows. Total inserted: 32400000
#   Inserted 100000 rows. Total inserted: 32500000
#   Inserted 100000 rows. Total inserted: 32600000
#   Inserted 100000 rows. Total inserted: 32700000
#   Inserted 100000 rows. Total inserted: 32800000
#   Inserted 100000 rows. Total inserted: 32900000
#   Inserted 100000 rows. Total inserted: 33000000
#   Inserted 100000 rows. Total inserted: 33100000
#   Inserted 100000 rows. Total inserted: 33200000
#   Inserted 100000 rows. Total inserted: 33300000
#   Inserted 100000 rows. Total inserted: 33400000
#   Inserted 100000 rows. Total inserted: 33500000
#   Inserted 100000 rows. Total inserted: 33600000
#   Inserted 100000 rows. Total inserted: 33700000
#   Inserted 100000 rows. Total inserted: 33800000
#   Inserted 100000 rows. Total inserted: 33900000
#   Inserted 100000 rows. Total inserted: 34000000
#   Inserted 100000 rows. Total inserted: 34100000
#   Inserted 100000 rows. Total inserted: 34200000
#   Inserted 100000 rows. Total inserted: 34300000
#   Inserted 100000 rows. Total inserted: 34400000
#   Inserted 100000 rows. Total inserted: 34500000
#   Inserted 100000 rows. Total inserted: 34600000
#   Inserted 100000 rows. Total inserted: 34700000
#   Inserted 100000 rows. Total inserted: 34800000
#   Inserted 100000 rows. Total inserted: 34900000
#   Inserted 100000 rows. Total inserted: 35000000
#   Inserted 100000 rows. Total inserted: 35100000
#   Inserted 100000 rows. Total inserted: 35200000
#   Inserted 100000 rows. Total inserted: 35300000
#   Inserted 100000 rows. Total inserted: 35400000
#   Inserted 100000 rows. Total inserted: 35500000
#   Inserted 100000 rows. Total inserted: 35600000
#   Inserted 100000 rows. Total inserted: 35700000
#   Inserted 100000 rows. Total inserted: 35800000
#   Inserted 100000 rows. Total inserted: 35900000
#   Inserted 100000 rows. Total inserted: 36000000
#   Inserted 100000 rows. Total inserted: 36100000
#   Inserted 100000 rows. Total inserted: 36200000
#   Inserted 100000 rows. Total inserted: 36300000
#   Inserted 100000 rows. Total inserted: 36400000
#   Inserted 100000 rows. Total inserted: 36500000
#   Inserted 100000 rows. Total inserted: 36600000
#   Inserted 100000 rows. Total inserted: 36700000
#   Inserted 100000 rows. Total inserted: 36800000
#   Inserted 100000 rows. Total inserted: 36900000
#   Inserted 100000 rows. Total inserted: 37000000
#   Inserted 100000 rows. Total inserted: 37100000
#   Inserted 100000 rows. Total inserted: 37200000
#   Inserted 100000 rows. Total inserted: 37300000
#   Inserted 100000 rows. Total inserted: 37400000
#   Inserted 100000 rows. Total inserted: 37500000
#   Inserted 100000 rows. Total inserted: 37600000
#   Inserted 100000 rows. Total inserted: 37700000
#   Inserted 100000 rows. Total inserted: 37800000
#   Inserted 100000 rows. Total inserted: 37900000
#   Inserted 100000 rows. Total inserted: 38000000
#   Inserted 100000 rows. Total inserted: 38100000
#   Inserted 100000 rows. Total inserted: 38200000
#   Inserted 100000 rows. Total inserted: 38300000
#   Inserted 100000 rows. Total inserted: 38400000
#   Inserted 100000 rows. Total inserted: 38500000
#   Inserted 100000 rows. Total inserted: 38600000
#   Inserted 100000 rows. Total inserted: 38700000
#   Inserted 100000 rows. Total inserted: 38800000
#   Inserted 100000 rows. Total inserted: 38900000
#   Inserted 100000 rows. Total inserted: 39000000
#   Inserted 100000 rows. Total inserted: 39100000
#   Inserted 100000 rows. Total inserted: 39200000
#   Inserted 100000 rows. Total inserted: 39300000
#   Inserted 100000 rows. Total inserted: 39400000
#   Inserted 100000 rows. Total inserted: 39500000
#   Inserted 100000 rows. Total inserted: 39600000
#   Inserted 100000 rows. Total inserted: 39700000
#   Inserted 100000 rows. Total inserted: 39800000
#   Inserted 100000 rows. Total inserted: 39900000
#   Inserted 100000 rows. Total inserted: 40000000
#   Inserted 100000 rows. Total inserted: 40100000
#   Inserted 100000 rows. Total inserted: 40200000
#   Inserted 100000 rows. Total inserted: 40300000
#   Inserted 100000 rows. Total inserted: 40400000
#   Inserted 100000 rows. Total inserted: 40500000
#   Inserted 100000 rows. Total inserted: 40600000
#   Inserted 100000 rows. Total inserted: 40700000
#   Inserted 100000 rows. Total inserted: 40800000
#   Inserted 100000 rows. Total inserted: 40900000
#   Inserted 100000 rows. Total inserted: 41000000
#   Inserted 100000 rows. Total inserted: 41100000
#   Inserted 100000 rows. Total inserted: 41200000
#   Inserted 100000 rows. Total inserted: 41300000
#   Inserted 100000 rows. Total inserted: 41400000
#   Inserted 100000 rows. Total inserted: 41500000
#   Inserted 100000 rows. Total inserted: 41600000
#   Inserted 100000 rows. Total inserted: 41700000
#   Inserted 100000 rows. Total inserted: 41800000
#   Inserted 100000 rows. Total inserted: 41900000
#   Inserted 100000 rows. Total inserted: 42000000
#   Inserted 100000 rows. Total inserted: 42100000
#   Inserted 100000 rows. Total inserted: 42200000
#   Inserted 100000 rows. Total inserted: 42300000
#   Inserted 100000 rows. Total inserted: 42400000
#   Inserted 100000 rows. Total inserted: 42500000
#   Inserted 100000 rows. Total inserted: 42600000
#   Inserted 100000 rows. Total inserted: 42700000
#   Inserted 100000 rows. Total inserted: 42800000
#   Inserted 100000 rows. Total inserted: 42900000
#   Inserted 100000 rows. Total inserted: 43000000
#   Inserted 100000 rows. Total inserted: 43100000
#   Inserted 100000 rows. Total inserted: 43200000
#   Inserted 100000 rows. Total inserted: 43300000
#   Inserted 100000 rows. Total inserted: 43400000
#   Inserted 100000 rows. Total inserted: 43500000
#   Inserted 100000 rows. Total inserted: 43600000
#   Inserted 100000 rows. Total inserted: 43700000
#   Inserted 100000 rows. Total inserted: 43800000
#   Inserted 100000 rows. Total inserted: 43900000
#   Inserted 100000 rows. Total inserted: 44000000
#   Inserted 100000 rows. Total inserted: 44100000
#   Inserted 100000 rows. Total inserted: 44200000
#   Inserted 100000 rows. Total inserted: 44300000
#   Inserted 100000 rows. Total inserted: 44400000
#   Inserted 100000 rows. Total inserted: 44500000
#   Inserted 100000 rows. Total inserted: 44600000
#   Inserted 100000 rows. Total inserted: 44700000
#   Inserted 100000 rows. Total inserted: 44800000
#   Inserted 100000 rows. Total inserted: 44900000
#   Inserted 100000 rows. Total inserted: 45000000
#   Inserted 100000 rows. Total inserted: 45100000
#   Inserted 100000 rows. Total inserted: 45200000
#   Inserted 100000 rows. Total inserted: 45300000
#   Inserted 100000 rows. Total inserted: 45400000
#   Inserted 100000 rows. Total inserted: 45500000
#   Inserted 100000 rows. Total inserted: 45600000
#   Inserted 100000 rows. Total inserted: 45700000
#   Inserted 100000 rows. Total inserted: 45800000
#   Inserted 100000 rows. Total inserted: 45900000
#   Inserted 100000 rows. Total inserted: 46000000
#   Inserted 100000 rows. Total inserted: 46100000
#   Inserted 100000 rows. Total inserted: 46200000
#   Inserted 100000 rows. Total inserted: 46300000
#   Inserted 100000 rows. Total inserted: 46400000
#   Inserted 100000 rows. Total inserted: 46500000
#   Inserted 100000 rows. Total inserted: 46600000
#   Inserted 100000 rows. Total inserted: 46700000
#   Inserted 100000 rows. Total inserted: 46800000
#   Inserted 100000 rows. Total inserted: 46900000
#   Inserted 100000 rows. Total inserted: 47000000
#   Inserted 100000 rows. Total inserted: 47100000
#   Inserted 100000 rows. Total inserted: 47200000
#   Inserted 100000 rows. Total inserted: 47300000
#   Inserted 100000 rows. Total inserted: 47400000
#   Inserted 100000 rows. Total inserted: 47500000
#   Inserted 100000 rows. Total inserted: 47600000
#   Inserted 100000 rows. Total inserted: 47700000
#   Inserted 100000 rows. Total inserted: 47800000
#   Inserted 100000 rows. Total inserted: 47900000
#   Inserted 100000 rows. Total inserted: 48000000
#   Inserted 100000 rows. Total inserted: 48100000
#   Inserted 100000 rows. Total inserted: 48200000
#   Inserted 100000 rows. Total inserted: 48300000
#   Inserted 100000 rows. Total inserted: 48400000
#   Inserted 100000 rows. Total inserted: 48500000
#   Inserted 100000 rows. Total inserted: 48600000
#   Inserted 100000 rows. Total inserted: 48700000
#   Inserted 100000 rows. Total inserted: 48800000
#   Inserted 100000 rows. Total inserted: 48900000
#   Inserted 100000 rows. Total inserted: 49000000
#   Inserted 100000 rows. Total inserted: 49100000
#   Inserted 100000 rows. Total inserted: 49200000
#   Inserted 100000 rows. Total inserted: 49300000
#   Inserted 100000 rows. Total inserted: 49400000
#   Inserted 100000 rows. Total inserted: 49500000
#   Inserted 100000 rows. Total inserted: 49600000
#   Inserted 100000 rows. Total inserted: 49700000
#   Inserted 100000 rows. Total inserted: 49800000
#   Inserted 100000 rows. Total inserted: 49900000
#   Inserted 100000 rows. Total inserted: 50000000
#   Inserted 100000 rows. Total inserted: 50100000
#   Inserted 100000 rows. Total inserted: 50200000
#   Inserted 100000 rows. Total inserted: 50300000
#   Inserted 100000 rows. Total inserted: 50400000
#   Inserted 100000 rows. Total inserted: 50500000
#   Inserted 100000 rows. Total inserted: 50600000
#   Inserted 100000 rows. Total inserted: 50700000
#   Inserted 100000 rows. Total inserted: 50800000
#   Inserted 100000 rows. Total inserted: 50900000
#   Inserted 100000 rows. Total inserted: 51000000
#   Inserted 100000 rows. Total inserted: 51100000
#   Inserted 100000 rows. Total inserted: 51200000
#   Inserted 100000 rows. Total inserted: 51300000
#   Inserted 100000 rows. Total inserted: 51400000
#   Inserted 100000 rows. Total inserted: 51500000
#   Inserted 100000 rows. Total inserted: 51600000
#   Inserted 100000 rows. Total inserted: 51700000
#   Inserted 100000 rows. Total inserted: 51800000
#   Inserted 100000 rows. Total inserted: 51900000
#   Inserted 100000 rows. Total inserted: 52000000
#   Inserted 100000 rows. Total inserted: 52100000
#   Inserted 100000 rows. Total inserted: 52200000
#   Inserted 100000 rows. Total inserted: 52300000
#   Inserted 100000 rows. Total inserted: 52400000
#   Inserted 100000 rows. Total inserted: 52500000
#   Inserted 100000 rows. Total inserted: 52600000
#   Inserted 100000 rows. Total inserted: 52700000
#   Inserted 100000 rows. Total inserted: 52800000
#   Inserted 100000 rows. Total inserted: 52900000
#   Inserted 100000 rows. Total inserted: 53000000
#   Inserted 100000 rows. Total inserted: 53100000
#   Inserted 100000 rows. Total inserted: 53200000
#   Inserted 100000 rows. Total inserted: 53300000
#   Inserted 100000 rows. Total inserted: 53400000
#   Inserted 100000 rows. Total inserted: 53500000
#   Inserted 100000 rows. Total inserted: 53600000
#   Inserted 100000 rows. Total inserted: 53700000
#   Inserted 100000 rows. Total inserted: 53800000
#   Inserted 100000 rows. Total inserted: 53900000
#   Inserted 100000 rows. Total inserted: 54000000
#   Inserted 100000 rows. Total inserted: 54100000
#   Inserted 100000 rows. Total inserted: 54200000
#   Inserted 100000 rows. Total inserted: 54300000
#   Inserted 100000 rows. Total inserted: 54400000
#   Inserted 100000 rows. Total inserted: 54500000
#   Inserted 100000 rows. Total inserted: 54600000
#   Inserted 100000 rows. Total inserted: 54700000
#   Inserted 100000 rows. Total inserted: 54800000
#   Inserted 100000 rows. Total inserted: 54900000
#   Inserted 100000 rows. Total inserted: 55000000
#   Inserted 100000 rows. Total inserted: 55100000
#   Inserted 100000 rows. Total inserted: 55200000
#   Inserted 100000 rows. Total inserted: 55300000
#   Inserted 100000 rows. Total inserted: 55400000
#   Inserted 100000 rows. Total inserted: 55500000
#   Inserted 100000 rows. Total inserted: 55600000
#   Inserted 100000 rows. Total inserted: 55700000
#   Inserted 100000 rows. Total inserted: 55800000
#   Inserted 100000 rows. Total inserted: 55900000
#   Inserted 100000 rows. Total inserted: 56000000
#   Inserted 100000 rows. Total inserted: 56100000
#   Inserted 100000 rows. Total inserted: 56200000
#   Inserted 100000 rows. Total inserted: 56300000
#   Inserted 100000 rows. Total inserted: 56400000
#   Inserted 100000 rows. Total inserted: 56500000
#   Inserted 100000 rows. Total inserted: 56600000
#   Inserted 100000 rows. Total inserted: 56700000
#   Inserted 100000 rows. Total inserted: 56800000
#   Inserted 100000 rows. Total inserted: 56900000
#   Inserted 100000 rows. Total inserted: 57000000
#   Inserted 100000 rows. Total inserted: 57100000
#   Inserted 100000 rows. Total inserted: 57200000
#   Inserted 100000 rows. Total inserted: 57300000
#   Inserted 100000 rows. Total inserted: 57400000
#   Inserted 100000 rows. Total inserted: 57500000
#   Inserted 100000 rows. Total inserted: 57600000
#   Inserted 100000 rows. Total inserted: 57700000
#   Inserted 100000 rows. Total inserted: 57800000
#   Inserted 100000 rows. Total inserted: 57900000
#   Inserted 100000 rows. Total inserted: 58000000
#   Inserted 100000 rows. Total inserted: 58100000
#   Inserted 100000 rows. Total inserted: 58200000
#   Inserted 100000 rows. Total inserted: 58300000
#   Inserted 100000 rows. Total inserted: 58400000
#   Inserted 100000 rows. Total inserted: 58500000
#   Inserted 100000 rows. Total inserted: 58600000
#   Inserted 100000 rows. Total inserted: 58700000
#   Inserted 100000 rows. Total inserted: 58800000
#   Inserted 100000 rows. Total inserted: 58900000
#   Inserted 100000 rows. Total inserted: 59000000
#   Inserted 100000 rows. Total inserted: 59100000
#   Inserted 100000 rows. Total inserted: 59200000
#   Inserted 100000 rows. Total inserted: 59300000
#   Inserted 100000 rows. Total inserted: 59400000
#   Inserted 100000 rows. Total inserted: 59500000
#   Inserted 100000 rows. Total inserted: 59600000
#   Inserted 100000 rows. Total inserted: 59700000
#   Inserted 100000 rows. Total inserted: 59800000
#   Inserted 100000 rows. Total inserted: 59900000
#   Inserted 100000 rows. Total inserted: 60000000
#   Inserted 100000 rows. Total inserted: 60100000
#   Inserted 100000 rows. Total inserted: 60200000
#   Inserted 100000 rows. Total inserted: 60300000
#   Inserted 100000 rows. Total inserted: 60400000
#   Inserted 100000 rows. Total inserted: 60500000
#   Inserted 100000 rows. Total inserted: 60600000
#   Inserted 100000 rows. Total inserted: 60700000
#   Inserted 100000 rows. Total inserted: 60800000
#   Inserted 100000 rows. Total inserted: 60900000
#   Inserted 100000 rows. Total inserted: 61000000
#   Inserted 100000 rows. Total inserted: 61100000
#   Inserted 100000 rows. Total inserted: 61200000
#   Inserted 100000 rows. Total inserted: 61300000
#   Inserted 100000 rows. Total inserted: 61400000
#   Inserted 100000 rows. Total inserted: 61500000
#   Inserted 100000 rows. Total inserted: 61600000
#   Inserted 100000 rows. Total inserted: 61700000
#   Inserted 100000 rows. Total inserted: 61800000
#   Inserted 100000 rows. Total inserted: 61900000
#   Inserted 100000 rows. Total inserted: 62000000
#   Inserted 100000 rows. Total inserted: 62100000
#   Inserted 100000 rows. Total inserted: 62200000
#   Inserted 100000 rows. Total inserted: 62300000
#   Inserted 100000 rows. Total inserted: 62400000
#   Inserted 100000 rows. Total inserted: 62500000
#   Inserted 100000 rows. Total inserted: 62600000
#   Inserted 100000 rows. Total inserted: 62700000
#   Inserted 100000 rows. Total inserted: 62800000
#   Inserted 100000 rows. Total inserted: 62900000
#   Inserted 100000 rows. Total inserted: 63000000
#   Inserted 100000 rows. Total inserted: 63100000
#   Inserted 100000 rows. Total inserted: 63200000
#   Inserted 100000 rows. Total inserted: 63300000
#   Inserted 100000 rows. Total inserted: 63400000
#   Inserted 100000 rows. Total inserted: 63500000
#   Inserted 100000 rows. Total inserted: 63600000
#   Inserted 100000 rows. Total inserted: 63700000
#   Inserted 100000 rows. Total inserted: 63800000
#   Inserted 100000 rows. Total inserted: 63900000
#   Inserted 100000 rows. Total inserted: 64000000
#   Inserted 100000 rows. Total inserted: 64100000
#   Inserted 100000 rows. Total inserted: 64200000
#   Inserted 100000 rows. Total inserted: 64300000
#   Inserted 100000 rows. Total inserted: 64400000
#   Inserted 100000 rows. Total inserted: 64500000
#   Inserted 100000 rows. Total inserted: 64600000
#   Inserted 100000 rows. Total inserted: 64700000
#   Inserted 100000 rows. Total inserted: 64800000
#   Inserted 100000 rows. Total inserted: 64900000
#   Inserted 100000 rows. Total inserted: 65000000
#   Inserted 100000 rows. Total inserted: 65100000
#   Inserted 100000 rows. Total inserted: 65200000
#   Inserted 100000 rows. Total inserted: 65300000
#   Inserted 100000 rows. Total inserted: 65400000
#   Inserted 100000 rows. Total inserted: 65500000
#   Inserted 100000 rows. Total inserted: 65600000
#   Inserted 100000 rows. Total inserted: 65700000
#   Inserted 100000 rows. Total inserted: 65800000
#   Inserted 100000 rows. Total inserted: 65900000
#   Inserted 100000 rows. Total inserted: 66000000
#   Inserted 100000 rows. Total inserted: 66100000
#   Inserted 100000 rows. Total inserted: 66200000
#   Inserted 100000 rows. Total inserted: 66300000
#   Inserted 100000 rows. Total inserted: 66400000
#   Inserted 100000 rows. Total inserted: 66500000
#   Inserted 100000 rows. Total inserted: 66600000
#   Inserted 100000 rows. Total inserted: 66700000
#   Inserted 100000 rows. Total inserted: 66800000
#   Inserted 100000 rows. Total inserted: 66900000
#   Inserted 100000 rows. Total inserted: 67000000
#   Inserted 100000 rows. Total inserted: 67100000
#   Inserted 100000 rows. Total inserted: 67200000
#   Inserted 100000 rows. Total inserted: 67300000
#   Inserted 100000 rows. Total inserted: 67400000
#   Inserted 100000 rows. Total inserted: 67500000
#   Inserted 100000 rows. Total inserted: 67600000
#   Inserted 100000 rows. Total inserted: 67700000
#   Inserted 100000 rows. Total inserted: 67800000
#   Inserted 100000 rows. Total inserted: 67900000
#   Inserted 100000 rows. Total inserted: 68000000
#   Inserted 100000 rows. Total inserted: 68100000
#   Inserted 100000 rows. Total inserted: 68200000
#   Inserted 100000 rows. Total inserted: 68300000
#   Inserted 100000 rows. Total inserted: 68400000
#   Inserted 100000 rows. Total inserted: 68500000
#   Inserted 100000 rows. Total inserted: 68600000
#   Inserted 100000 rows. Total inserted: 68700000
#   Inserted 100000 rows. Total inserted: 68800000
#   Inserted 100000 rows. Total inserted: 68900000
#   Inserted 100000 rows. Total inserted: 69000000
#   Inserted 100000 rows. Total inserted: 69100000
#   Inserted 100000 rows. Total inserted: 69200000
#   Inserted 100000 rows. Total inserted: 69300000
#   Inserted 100000 rows. Total inserted: 69400000
#   Inserted 100000 rows. Total inserted: 69500000
#   Inserted 100000 rows. Total inserted: 69600000
#   Inserted 100000 rows. Total inserted: 69700000
#   Inserted 100000 rows. Total inserted: 69800000
#   Inserted 100000 rows. Total inserted: 69900000
#   Inserted 100000 rows. Total inserted: 70000000
#   Inserted 100000 rows. Total inserted: 70100000
#   Inserted 100000 rows. Total inserted: 70200000
#   Inserted 100000 rows. Total inserted: 70300000
#   Inserted 100000 rows. Total inserted: 70400000
#   Inserted 100000 rows. Total inserted: 70500000
#   Inserted 100000 rows. Total inserted: 70600000
#   Inserted 100000 rows. Total inserted: 70700000
#   Inserted 100000 rows. Total inserted: 70800000
#   Inserted 100000 rows. Total inserted: 70900000
#   Inserted 100000 rows. Total inserted: 71000000
#   Inserted 100000 rows. Total inserted: 71100000
#   Inserted 100000 rows. Total inserted: 71200000
#   Inserted 100000 rows. Total inserted: 71300000
#   Inserted 100000 rows. Total inserted: 71400000
#   Inserted 100000 rows. Total inserted: 71500000
#   Inserted 100000 rows. Total inserted: 71600000
#   Inserted 100000 rows. Total inserted: 71700000
#   Inserted 100000 rows. Total inserted: 71800000
#   Inserted 100000 rows. Total inserted: 71900000
#   Inserted 100000 rows. Total inserted: 72000000
#   Inserted 100000 rows. Total inserted: 72100000
#   Inserted 100000 rows. Total inserted: 72200000
#   Inserted 100000 rows. Total inserted: 72300000
#   Inserted 100000 rows. Total inserted: 72400000
#   Inserted 100000 rows. Total inserted: 72500000
#   Inserted 100000 rows. Total inserted: 72600000
#   Inserted 100000 rows. Total inserted: 72700000
#   Inserted 100000 rows. Total inserted: 72800000
#   Inserted 100000 rows. Total inserted: 72900000
#   Inserted 100000 rows. Total inserted: 73000000
#   Inserted 100000 rows. Total inserted: 73100000
#   Inserted 100000 rows. Total inserted: 73200000
#   Inserted 100000 rows. Total inserted: 73300000
#   Inserted 100000 rows. Total inserted: 73400000
#   Inserted 100000 rows. Total inserted: 73500000
#   Inserted 100000 rows. Total inserted: 73600000
#   Inserted 100000 rows. Total inserted: 73700000
#   Inserted 100000 rows. Total inserted: 73800000
#   Inserted 100000 rows. Total inserted: 73900000
#   Inserted 100000 rows. Total inserted: 74000000
#   Inserted 100000 rows. Total inserted: 74100000
#   Inserted 100000 rows. Total inserted: 74200000
#   Inserted 100000 rows. Total inserted: 74300000
#   Inserted 100000 rows. Total inserted: 74400000
#   Inserted 100000 rows. Total inserted: 74500000
#   Inserted 100000 rows. Total inserted: 74600000
#   Inserted 100000 rows. Total inserted: 74700000
#   Inserted 100000 rows. Total inserted: 74800000
#   Inserted 100000 rows. Total inserted: 74900000
#   Inserted 100000 rows. Total inserted: 75000000
#   Inserted 100000 rows. Total inserted: 75100000
#   Inserted 100000 rows. Total inserted: 75200000
#   Inserted 100000 rows. Total inserted: 75300000
#   Inserted 100000 rows. Total inserted: 75400000
#   Inserted 100000 rows. Total inserted: 75500000
#   Inserted 100000 rows. Total inserted: 75600000
#   Inserted 100000 rows. Total inserted: 75700000
#   Inserted 100000 rows. Total inserted: 75800000
#   Inserted 100000 rows. Total inserted: 75900000
#   Inserted 100000 rows. Total inserted: 76000000
#   Inserted 100000 rows. Total inserted: 76100000
#   Inserted 100000 rows. Total inserted: 76200000
#   Inserted 100000 rows. Total inserted: 76300000
#   Inserted 100000 rows. Total inserted: 76400000
#   Inserted 100000 rows. Total inserted: 76500000
#   Inserted 100000 rows. Total inserted: 76600000
#   Inserted 100000 rows. Total inserted: 76700000
#   Inserted 100000 rows. Total inserted: 76800000
#   Inserted 100000 rows. Total inserted: 76900000
#   Inserted 100000 rows. Total inserted: 77000000
#   Inserted 100000 rows. Total inserted: 77100000
#   Inserted 100000 rows. Total inserted: 77200000
#   Inserted 100000 rows. Total inserted: 77300000
#   Inserted 100000 rows. Total inserted: 77400000
#   Inserted 100000 rows. Total inserted: 77500000
#   Inserted 100000 rows. Total inserted: 77600000
#   Inserted 100000 rows. Total inserted: 77700000
#   Inserted 100000 rows. Total inserted: 77800000
#   Inserted 100000 rows. Total inserted: 77900000
#   Inserted 100000 rows. Total inserted: 78000000
#   Inserted 100000 rows. Total inserted: 78100000
#   Inserted 100000 rows. Total inserted: 78200000
#   Inserted 100000 rows. Total inserted: 78300000
#   Inserted 100000 rows. Total inserted: 78400000
#   Inserted 100000 rows. Total inserted: 78500000
#   Inserted 100000 rows. Total inserted: 78600000
#   Inserted 100000 rows. Total inserted: 78700000
#   Inserted 100000 rows. Total inserted: 78800000
#   Inserted 100000 rows. Total inserted: 78900000
#   Inserted 100000 rows. Total inserted: 79000000
#   Inserted 100000 rows. Total inserted: 79100000
#   Inserted 100000 rows. Total inserted: 79200000
#   Inserted 100000 rows. Total inserted: 79300000
#   Inserted 100000 rows. Total inserted: 79400000
#   Inserted 100000 rows. Total inserted: 79500000
#   Inserted 100000 rows. Total inserted: 79600000
#   Inserted 100000 rows. Total inserted: 79700000
#   Inserted 100000 rows. Total inserted: 79800000
#   Inserted 100000 rows. Total inserted: 79900000
#   Inserted 100000 rows. Total inserted: 80000000
#   Inserted 100000 rows. Total inserted: 80100000
#   Inserted 100000 rows. Total inserted: 80200000
#   Inserted 100000 rows. Total inserted: 80300000
#   Inserted 100000 rows. Total inserted: 80400000
#   Inserted 100000 rows. Total inserted: 80500000
#   Inserted 100000 rows. Total inserted: 80600000
#   Inserted 100000 rows. Total inserted: 80700000
#   Inserted 100000 rows. Total inserted: 80800000
#   Inserted 100000 rows. Total inserted: 80900000
#   Inserted 100000 rows. Total inserted: 81000000
#   Inserted 100000 rows. Total inserted: 81100000
#   Inserted 100000 rows. Total inserted: 81200000
#   Inserted 100000 rows. Total inserted: 81300000
#   Inserted 100000 rows. Total inserted: 81400000
#   Inserted 100000 rows. Total inserted: 81500000
#   Inserted 100000 rows. Total inserted: 81600000
#   Inserted 100000 rows. Total inserted: 81700000
#   Inserted 100000 rows. Total inserted: 81800000
#   Inserted 100000 rows. Total inserted: 81900000
#   Inserted 100000 rows. Total inserted: 82000000
#   Inserted 100000 rows. Total inserted: 82100000
#   Inserted 100000 rows. Total inserted: 82200000
#   Inserted 100000 rows. Total inserted: 82300000
#   Inserted 100000 rows. Total inserted: 82400000
#   Inserted 100000 rows. Total inserted: 82500000
#   Inserted 100000 rows. Total inserted: 82600000
#   Inserted 100000 rows. Total inserted: 82700000
#   Inserted 100000 rows. Total inserted: 82800000
#   Inserted 100000 rows. Total inserted: 82900000
#   Inserted 100000 rows. Total inserted: 83000000
#   Inserted 100000 rows. Total inserted: 83100000
#   Inserted 100000 rows. Total inserted: 83200000
#   Inserted 100000 rows. Total inserted: 83300000
#   Inserted 100000 rows. Total inserted: 83400000
#   Inserted 100000 rows. Total inserted: 83500000
#   Inserted 100000 rows. Total inserted: 83600000
#   Inserted 100000 rows. Total inserted: 83700000
#   Inserted 100000 rows. Total inserted: 83800000
#   Inserted 100000 rows. Total inserted: 83900000
#   Inserted 100000 rows. Total inserted: 84000000
#   Inserted 100000 rows. Total inserted: 84100000
#   Inserted 100000 rows. Total inserted: 84200000
#   Inserted 100000 rows. Total inserted: 84300000
#   Inserted 100000 rows. Total inserted: 84400000
#   Inserted 100000 rows. Total inserted: 84500000
#   Inserted 100000 rows. Total inserted: 84600000
#   Inserted 100000 rows. Total inserted: 84700000
#   Inserted 100000 rows. Total inserted: 84800000
#   Inserted 100000 rows. Total inserted: 84900000
#   Inserted 100000 rows. Total inserted: 85000000
#   Inserted 100000 rows. Total inserted: 85100000
#   Inserted 100000 rows. Total inserted: 85200000
#   Inserted 100000 rows. Total inserted: 85300000
#   Inserted 100000 rows. Total inserted: 85400000
#   Inserted 100000 rows. Total inserted: 85500000
#   Inserted 100000 rows. Total inserted: 85600000
#   Inserted 100000 rows. Total inserted: 85700000
#   Inserted 100000 rows. Total inserted: 85800000
#   Inserted 100000 rows. Total inserted: 85900000
#   Inserted 100000 rows. Total inserted: 86000000
#   Inserted 100000 rows. Total inserted: 86100000
#   Inserted 100000 rows. Total inserted: 86200000
#   Inserted 100000 rows. Total inserted: 86300000
#   Inserted 100000 rows. Total inserted: 86400000
#   Inserted 100000 rows. Total inserted: 86500000
#   Inserted 100000 rows. Total inserted: 86600000
#   Inserted 100000 rows. Total inserted: 86700000
#   Inserted 100000 rows. Total inserted: 86800000
#   Inserted 100000 rows. Total inserted: 86900000
#   Inserted 100000 rows. Total inserted: 87000000
#   Inserted 100000 rows. Total inserted: 87100000
#   Inserted 100000 rows. Total inserted: 87200000
#   Inserted 100000 rows. Total inserted: 87300000
#   Inserted 100000 rows. Total inserted: 87400000
#   Inserted 100000 rows. Total inserted: 87500000
#   Inserted 100000 rows. Total inserted: 87600000
#   Inserted 100000 rows. Total inserted: 87700000
#   Inserted 100000 rows. Total inserted: 87800000
#   Inserted 100000 rows. Total inserted: 87900000
#   Inserted 100000 rows. Total inserted: 88000000
#   Inserted 100000 rows. Total inserted: 88100000
#   Inserted 100000 rows. Total inserted: 88200000
#   Inserted 100000 rows. Total inserted: 88300000
#   Inserted 100000 rows. Total inserted: 88400000
#   Inserted 100000 rows. Total inserted: 88500000
#   Inserted 100000 rows. Total inserted: 88600000
#   Inserted 100000 rows. Total inserted: 88700000
#   Inserted 100000 rows. Total inserted: 88800000
#   Inserted 100000 rows. Total inserted: 88900000
#   Inserted 100000 rows. Total inserted: 89000000
#   Inserted 100000 rows. Total inserted: 89100000
#   Inserted 100000 rows. Total inserted: 89200000
#   Inserted 100000 rows. Total inserted: 89300000
#   Inserted 100000 rows. Total inserted: 89400000
#   Inserted 100000 rows. Total inserted: 89500000
#   Inserted 100000 rows. Total inserted: 89600000
#   Inserted 100000 rows. Total inserted: 89700000
#   Inserted 100000 rows. Total inserted: 89800000
#   Inserted 100000 rows. Total inserted: 89900000
#   Inserted 100000 rows. Total inserted: 90000000
#   Inserted 100000 rows. Total inserted: 90100000
#   Inserted 100000 rows. Total inserted: 90200000
#   Inserted 100000 rows. Total inserted: 90300000
#   Inserted 100000 rows. Total inserted: 90400000
#   Inserted 100000 rows. Total inserted: 90500000
#   Inserted 100000 rows. Total inserted: 90600000
#   Inserted 100000 rows. Total inserted: 90700000
#   Inserted 100000 rows. Total inserted: 90800000
#   Inserted 100000 rows. Total inserted: 90900000
#   Inserted 100000 rows. Total inserted: 91000000
#   Inserted 100000 rows. Total inserted: 91100000
#   Inserted 100000 rows. Total inserted: 91200000
#   Inserted 100000 rows. Total inserted: 91300000
#   Inserted 100000 rows. Total inserted: 91400000
#   Inserted 100000 rows. Total inserted: 91500000
#   Inserted 100000 rows. Total inserted: 91600000
#   Inserted 100000 rows. Total inserted: 91700000
#   Inserted 100000 rows. Total inserted: 91800000
#   Inserted 100000 rows. Total inserted: 91900000
#   Inserted 100000 rows. Total inserted: 92000000
#   Inserted 100000 rows. Total inserted: 92100000
#   Inserted 100000 rows. Total inserted: 92200000
#   Inserted 100000 rows. Total inserted: 92300000
#   Inserted 100000 rows. Total inserted: 92400000
#   Inserted 100000 rows. Total inserted: 92500000
#   Inserted 100000 rows. Total inserted: 92600000
#   Inserted 100000 rows. Total inserted: 92700000
#   Inserted 100000 rows. Total inserted: 92800000
#   Inserted 100000 rows. Total inserted: 92900000
#   Inserted 100000 rows. Total inserted: 93000000
#   Inserted 100000 rows. Total inserted: 93100000
#   Inserted 100000 rows. Total inserted: 93200000
#   Inserted 100000 rows. Total inserted: 93300000
#   Inserted 100000 rows. Total inserted: 93400000
#   Inserted 100000 rows. Total inserted: 93500000
#   Inserted 100000 rows. Total inserted: 93600000
#   Inserted 100000 rows. Total inserted: 93700000
#   Inserted 100000 rows. Total inserted: 93800000
#   Inserted 100000 rows. Total inserted: 93900000
#   Inserted 100000 rows. Total inserted: 94000000
#   Inserted 100000 rows. Total inserted: 94100000
#   Inserted 100000 rows. Total inserted: 94200000
#   Inserted 100000 rows. Total inserted: 94300000
#   Inserted 100000 rows. Total inserted: 94400000
#   Inserted 100000 rows. Total inserted: 94500000
#   Inserted 100000 rows. Total inserted: 94600000
#   Inserted 100000 rows. Total inserted: 94700000
#   Inserted 100000 rows. Total inserted: 94800000
#   Inserted 69699 rows. Total inserted: 94869699
# Successfully exported all data to MySQL table 'PrinterData'.
# MySQL connection closed.
